# %%
base = 1504170715041707
modular = 4503599627370517
newcoin = lambda x: base*x%modular

# %%
i = 1
latestcoin = newcoin(i)
ecoin = [(i, latestcoin)]
diffs = []
dif = 1

ct = 0
while latestcoin>1:
    dif = 1
    for di, minus in diffs:
        if testcoin+minus>0:
            dif=di
            break
    i+=dif
    testcoin = newcoin(i)
    if testcoin<latestcoin:
        latestcoin=testcoin
        prev_i, prev_coin = ecoin[-1]
        ecoin.append((i, latestcoin))
        diffs.append((i-prev_i, latestcoin-prev_coin))
        print(i, latestcoin)
    
sum([c[1] for c in ecoin])
# Out:
# 3 8912517754604
# 506 2044785486369
# 2527 1311409677241
# 4548 578033868113
# 11117 422691927098
# 17686 267349986083
# 24255 112008045068
# 55079 68674149121
# 85903 25340253174
# 202630 7346610401
# 724617 4046188430
# 1246604 745766459
# 6755007 428410324
# 12263410 111054189
# 42298633 15806432
# 326125654 15397267
# 609952675 14988102
# 893779696 14578937
# 1177606717 14169772
# 1461433738 13760607
# 1745260759 13351442
# 2029087780 12942277
# 2312914801 12533112
# 2596741822 12123947
# 2880568843 11714782
# 3164395864 11305617
# 3448222885 10896452
# 3732049906 10487287
# 4015876927 10078122
# 4299703948 9668957
# 4583530969 9259792
# 4867357990 8850627
# 5151185011 8441462
# 5435012032 8032297
# 5718839053 7623132
# 6002666074 7213967
# 6286493095 6804802
# 6570320116 6395637
# 6854147137 5986472
# 7137974158 5577307
# 7421801179 5168142
# 7705628200 4758977
# 7989455221 4349812
# 8273282242 3940647
# 8557109263 3531482
# 8840936284 3122317
# 9124763305 2713152
# ...
