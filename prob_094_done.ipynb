# %%
from time import time
from math import sqrt, gcd

# %%
def isSquare(x):
    testsq = int(sqrt(x))
    return x == testsq*testsq

# %%
L_max = 10**9
x_max = L_max//3
sumL = 0 
t0 = time()
for x in range(3, x_max+1,2):
    if (x-1) % (10**6) ==0:
        print(x,time()-t0, sumL)
    y = (x+1)//2
    if isSquare(x*x-y*y):
        sumL += x+x+x+1
        print(x,y)
    y = (x-1)//2
    if isSquare(x*x-y*y):
        sumL += x+x+x-1
        print(x,y)
print(x, sumL)
# Out:
# 5 3
# 17 8
# 65 33
# 241 120
# 901 451
# 3361 1680
# 12545 6273
# 46817 23408
# 174725 87363
# 652081 326040
# 1000001 0.7814500331878662 2672274
# 2000001 1.5734169483184814 2672274
# 2433601 1216801
# 3000001 2.3546645641326904 9973078
# 4000001 3.133639335632324 9973078
# 5000001 3.944504737854004 9973078
# 6000001 4.76125955581665 9973078
# 7000001 5.547168731689453 9973078
# 8000001 6.34846568107605 9973078
# 9000001 7.1921916007995605 9973078
# 9082321 4541160
# 10000001 8.014857292175293 37220040
# 11000001 8.782100200653076 37220040
# 12000001 9.616426467895508 37220040
# 13000001 10.401548147201538 37220040
# 14000001 11.224868297576904 37220040
# 15000001 12.03073763847351 37220040
# 16000001 12.816412210464478 37220040
# 17000001 13.58078646659851 37220040
# 18000001 14.357056140899658 37220040
# 19000001 15.127606630325317 37220040
# 20000001 15.900905847549438 37220040
# 21000001 16.663631200790405 37220040
# 22000001 17.440096616744995 37220040
# ...

# %%
x
# Out:
# 333333333

# %%
# 518408346 correct solution
