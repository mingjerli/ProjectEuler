# %%
from time import time

# %%
L = 50

# %%
count=0
t0=time()
for y1 in range(L+1):
    for x1 in range(L+1):
        for y2 in range(L+1):
            for x2 in range(L+1):
                if y1*x2>y2*x1:
                    counta+=1
                    L01s = x1*x1+y1*y1
                    L02s = x2*x2+y2*y2
                    dx = x1-x2
                    dy = y1-y2
                    L12s = dx*dx+dy*dy
                    if L01s+L02s==L12s or L01s+L12s==L02s or L02s+L12s==L01s:
#                         print((x1,y1),(x2,y2),L01s,L02s,L12s)
                        count+=1
    print(y1,count,time()-t0)

print(count)
# Out:
# 0 0 0.019549131393432617
# 1 151 0.046681880950927734
# 2 307 0.07760930061340332
# 3 468 0.11176180839538574
# 4 640 0.14915108680725098
# 5 817 0.18984556198120117
# 6 1016 0.2352144718170166
# 7 1211 0.2831854820251465
# 8 1428 0.3368866443634033
# 9 1649 0.38991475105285645
# 10 1892 0.4456965923309326
# 11 2115 0.5040736198425293
# 12 2402 0.5676839351654053
# 13 2641 0.6306381225585938
# 14 2916 0.6958868503570557
# 15 3215 0.7639093399047852
# 16 3514 0.8372354507446289
# 17 3771 0.909844160079956
# 18 4100 0.9845421314239502
# 19 4373 1.0640063285827637
# 20 4723 1.1426668167114258
# 21 5048 1.2233524322509766
# 22 5368 1.3072936534881592
# 23 5649 1.394946575164795
# 24 6029 1.4802722930908203
# 25 6346 1.5674083232879639
# 26 6667 1.6590588092803955
# 27 6987 1.7489497661590576
# 28 7333 1.8491630554199219
# 29 7621 1.9598758220672607
# 30 7986 2.060776948928833
# 31 8276 2.1621153354644775
# 32 8603 2.2758288383483887
# 33 8921 2.3849542140960693
# ...

# %%
# 14234 correct solution @ 2017-03-22 5:55
