# %%
from math import sqrt

# %%
sqrt(2)
# Out:
# 1.4142135623730951

# %%
14142*14142
# Out:
# 199996164

# %%
1414213562373095011111111111111111111111111111111111111 **2
# Out:
# 1999999999999999893394947931760444567901234567901234567586964887373880120987654320987654320987654320987654321

# %%
result = 0
for n in range(1,100):
    a0 = int(sqrt(n))
    if a0*a0 != n:
        result += a0
        for d in range(1,99+1):
            a0 *= 10
            i = 0
            while i < 10 and a0*a0 <= n*(10**(d+d)):
    #             print(i,a0*a0,n*(10**(d+d)))
                a0+=1
                i+=1
            a0-=1
            result+=(i-1)
    #         print(d,result,a0)
        print(n,result,a0)
# Out:
# 2 475 1414213562373095048801688724209698078569671875376948073176679737990732478462107038850387534327641572
# 3 916 1732050807568877293527446341505872366942805253810380628055806979451933016908800037081146186757248575
# 5 1389 2236067977499789696409173668731276235440618359611525724270897245410520925637804899414414408378782274
# 6 1860 2449489742783178098197284074705891391965947480656670128432692567250960377457315026539859433104640234
# 7 2258 2645751311064590590501615753639260425710259183082450180368334459201068823230283627760392886474543610
# 8 2723 2828427124746190097603377448419396157139343750753896146353359475981464956924214077700775068655283145
# 10 3182 3162277660168379331998893544432718533719555139325216826857504852792594438639238221344248108379300295
# 11 3666 3316624790355399849114932736670686683927088545589353597058682146116484642609043846708843399128290650
# 12 4072 3464101615137754587054892683011744733885610507620761256111613958903866033817600074162292373514497151
# ...

# %%
result
# Out:
# 40886

# %%
# 40886 correct answer
